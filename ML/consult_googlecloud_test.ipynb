# %%
from google.cloud import bigquery
import pandas as pd
import os

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "credencial.json"

# %%
# Configura tu proyecto y tu dataset
project_id = 'pure-hue-399113'
dataset_id = 'datos_crudos_google'
table_id = 'cualidades_google_crudo'
limite = 10

# %%
# Inicializa el cliente de BigQuery
client = bigquery.Client()

# %%
# Construye la consulta SQL
query = f"""
    SELECT *
    FROM `{project_id}.{dataset_id}.{table_id}`
    LIMIT {limite}
"""

# %%
# Ejecuta la consulta y obtén los resultados
query_job = client.query(query)
results = query_job.result()

# %%
rows = []

# Itera sobre las filas y almacena los datos en la lista
for row in results:
    print(row)
    rows.append(row)
# Out:
# Row(('0x8805a2a887bbe777:0xb6c14a56e8897c0f', 'Takeout, Dine-in', None, None, None, None, None, None, None, None, 'Lunch, Catering', 'Debit cards, NFC mobile payments', None, None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x8805bd4fca30e96f:0x66219cdc260035ce', 'No-contact delivery, Delivery, Takeout, Dine-in', None, None, None, 'Wheelchair accessible entrance', None, None, None, None, None, None, None, None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x8803b8bdd500523b:0x18fb306e02f45d7e', 'Delivery', None, None, None, 'Wheelchair accessible entrance', None, None, None, None, None, None, None, None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x89e20ba5af52c0c1:0x92f11660e7b2d2a6', 'Curbside pickup, No-contact delivery, Delivery, Takeout, Dine-in', None, None, None, 'Wheelchair accessible entrance', None, None, None, None, None, None, None, None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x4cb325f35a2b7e11:0x8b9cdab6cbb1d041', 'In-store pickup, In-store shopping, Takeout, Delivery, Dine-in', None, 'LGBTQ friendly', None, None, None, None, None, None, None, 'Checks, Debit cards', 'Quick visit', 'Identifies as women-led', None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x809947d67f3baac7:0xb758b7385964474a', None, None, None, None, None, None, None, None, None, None, None, None, None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x87530f6b7c148af9:0xc1a0082380748ae9', 'In-store shopping, Delivery', None, None, None, 'Wheelchair accessible entrance', None, None, None, None, None, None, 'Quick visit', None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x80c8dbf46bfec88f:0x54c72a50a08deecd', 'Curbside pickup, No-contact delivery, Delivery, Takeout, Dine-in', None, None, None, 'Wheelchair accessible entrance', None, None, None, None, None, None, None, None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x8752f4bac16989eb:0xb64c18a2a70c97ca', 'In-store pickup, In-store shopping', 'Mask required, Staff wear masks, Staff required to disinfect surfaces between visits, Safety dividers at checkout', 'Great produce', None, 'Wheelchair accessible entrance', None, None, None, None, None, 'Debit cards, NFC mobile payments, Credit cards', 'Quick visit', None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})
# Row(('0x8806fe97839515f7:0xa484e639446936d4', 'Curbside pickup, No-contact delivery, Delivery, Takeout, Dine-in', None, None, None, 'Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible restroom', None, None, None, None, None, None, None, None, None), {'string_field_0': 0, 'string_field_1': 1, 'string_field_2': 2, 'string_field_3': 3, 'string_field_4': 4, 'string_field_5': 5, 'string_field_6': 6, 'string_field_7': 7, 'string_field_8': 8, 'string_field_9': 9, 'string_field_10': 10, 'string_field_11': 11, 'string_field_12': 12, 'string_field_13': 13, 'string_field_14': 14})

# %%
[list(x.values()) for x in rows]
# Out:
# [['0x8805a2a887bbe777:0xb6c14a56e8897c0f',
#   'Takeout, Dine-in',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Lunch, Catering',
#   'Debit cards, NFC mobile payments',
#   None,
#   None,
#   None],
#  ['0x8805bd4fca30e96f:0x66219cdc260035ce',
#   'No-contact delivery, Delivery, Takeout, Dine-in',
#   None,
#   None,
#   None,
#   'Wheelchair accessible entrance',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['0x8803b8bdd500523b:0x18fb306e02f45d7e',
#   'Delivery',
#   None,
#   None,
#   None,
#   'Wheelchair accessible entrance',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['0x89e20ba5af52c0c1:0x92f11660e7b2d2a6',
#   'Curbside pickup, No-contact delivery, Delivery, Takeout, Dine-in',
#   None,
#   None,
#   None,
#   'Wheelchair accessible entrance',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['0x4cb325f35a2b7e11:0x8b9cdab6cbb1d041',
#   'In-store pickup, In-store shopping, Takeout, Delivery, Dine-in',
#   None,
#   'LGBTQ friendly',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Checks, Debit cards',
#   'Quick visit',
#   'Identifies as women-led',
#   None],
#  ['0x809947d67f3baac7:0xb758b7385964474a',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['0x87530f6b7c148af9:0xc1a0082380748ae9',
#   'In-store shopping, Delivery',
#   None,
#   None,
#   None,
#   'Wheelchair accessible entrance',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Quick visit',
#   None,
#   None],
#  ['0x80c8dbf46bfec88f:0x54c72a50a08deecd',
#   'Curbside pickup, No-contact delivery, Delivery, Takeout, Dine-in',
#   None,
#   None,
#   None,
#   'Wheelchair accessible entrance',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['0x8752f4bac16989eb:0xb64c18a2a70c97ca',
#   'In-store pickup, In-store shopping',
#   'Mask required, Staff wear masks, Staff required to disinfect surfaces between visits, Safety dividers at checkout',
#   'Great produce',
#   None,
#   'Wheelchair accessible entrance',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Debit cards, NFC mobile payments, Credit cards',
#   'Quick visit',
#   None,
#   None],
#  ['0x8806fe97839515f7:0xa484e639446936d4',
#   'Curbside pickup, No-contact delivery, Delivery, Takeout, Dine-in',
#   None,
#   None,
#   None,
#   'Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible restroom',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None]]

# %%
list(rows[0].keys())
# Out:
# ['string_field_0',
#  'string_field_1',
#  'string_field_2',
#  'string_field_3',
#  'string_field_4',
#  'string_field_5',
#  'string_field_6',
#  'string_field_7',
#  'string_field_8',
#  'string_field_9',
#  'string_field_10',
#  'string_field_11',
#  'string_field_12',
#  'string_field_13',
#  'string_field_14']

# %%
# Convierte los resultados en un DataFrame de pandas
results_df = pd.DataFrame(data=[list(x.values()) for x in rows], columns=list(rows[0].keys()))
results_df
# Out:
#                           string_field_0  \
# 0  0x8805a2a887bbe777:0xb6c14a56e8897c0f
# 1  0x8805bd4fca30e96f:0x66219cdc260035ce
# 2  0x8803b8bdd500523b:0x18fb306e02f45d7e
# 3  0x89e20ba5af52c0c1:0x92f11660e7b2d2a6
# 4  0x4cb325f35a2b7e11:0x8b9cdab6cbb1d041
# 5  0x809947d67f3baac7:0xb758b7385964474a
# 6  0x87530f6b7c148af9:0xc1a0082380748ae9
# 7  0x80c8dbf46bfec88f:0x54c72a50a08deecd
# 8  0x8752f4bac16989eb:0xb64c18a2a70c97ca
# 9  0x8806fe97839515f7:0xa484e639446936d4
#
#                                       string_field_1  \
# 0                                   Takeout, Dine-in
# 1    No-contact delivery, Delivery, Takeout, Dine-in
# 2                                           Delivery
# 3  Curbside pickup, No-contact delivery, Delivery...
# 4  In-store pickup, In-store shopping, Takeout, D...
# 5                                               None
# 6                        In-store shopping, Delivery
# 7  Curbside pickup, No-contact delivery, Delivery...
# 8                 In-store pickup, In-store shopping
# 9  Curbside pickup, No-contact delivery, Delivery...
#
#                                       string_field_2  string_field_3  \
# 0                                               None            None
# 1                                               None            None
# 2                                               None            None
# 3                                               None            None
# 4                                               None  LGBTQ friendly
# 5                                               None            None
# 6                                               None            None
# 7                                               None            None
# 8  Mask required, Staff wear masks, Staff require...   Great produce
# 9                                               None            None
#
#   string_field_4                                     string_field_5  \
# 0           None                                               None
# 1           None                     Wheelchair accessible entrance
# 2           None                     Wheelchair accessible entrance
# 3           None                     Wheelchair accessible entrance
# 4           None                                               None
# 5           None                                               None
# 6           None                     Wheelchair accessible entrance
# 7           None                     Wheelchair accessible entrance
# 8           None                     Wheelchair accessible entrance
# 9           None  Wheelchair accessible entrance, Wheelchair acc...
#
#   string_field_6 string_field_7 string_field_8 string_field_9  \
# 0           None           None           None           None
# 1           None           None           None           None
# 2           None           None           None           None
# 3           None           None           None           None
# 4           None           None           None           None
# 5           None           None           None           None
# 6           None           None           None           None
# 7           None           None           None           None
# 8           None           None           None           None
# 9           None           None           None           None
#
#    string_field_10                                 string_field_11  \
# 0  Lunch, Catering                Debit cards, NFC mobile payments
# 1             None                                            None
# 2             None                                            None
# 3             None                                            None
# 4             None                             Checks, Debit cards
# 5             None                                            None
# 6             None                                            None
# 7             None                                            None
# 8             None  Debit cards, NFC mobile payments, Credit cards
# 9             None                                            None
#
#   string_field_12          string_field_13 string_field_14
# 0            None                     None            None
# 1            None                     None            None
# 2            None                     None            None
# 3            None                     None            None
# 4     Quick visit  Identifies as women-led            None
# 5            None                     None            None
# 6     Quick visit                     None            None
# 7            None                     None            None
# 8     Quick visit                     None            None
# 9            None                     None            None
