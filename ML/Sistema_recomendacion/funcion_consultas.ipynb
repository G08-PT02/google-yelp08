# %%
from google.cloud import bigquery
import pandas as pd
import os

# %%
def consulta():
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../credencial.json"

    client = bigquery.Client()

    query = f"""
    SELECT *
    FROM `pure-hue-399113.googleBase.Restaurantes`
    """

    query_job = client.query(query)
    results = query_job.result()

    rows = []
    for row in results:
        rows.append(row)

    results_df = pd.DataFrame(data=[list(x.values()) for x in rows], columns=list(rows[0].keys()))
    return results_df

# %%
'''
project_id = 'pure-hue-399113'
dataset_id = 'datos_crudos_google'
table_id = 'cualidades_google_crudo'
limite = 10
'''

# %%
consulta()
# Out:
#                                      name  \
# 0                     Roux's Roadhouse 73
# 1     Rita Supermarket and restaurants #2
# 2               Mr Scott’s Tavern & Grill
# 3                Chi Ku Pan-Asian Kitchen
# 4                         Man Yee Express
# ...                                   ...
# 3117                                  Fin
# 3118                  Second Street Grill
# 3119                            Tek Nique
# 3120                                 Pago
# 3121                  Il Angolo Resto-Bar
#
#                                                 address  \
# 0     Roux's Roadhouse 73, 784 WI-73, Nekoosa, WI 54457
# 1     Rita Supermarket and restaurants #2, 422 Belmo...
# 2     Mr Scott’s Tavern & Grill, W7318 WI-86, Tomaha...
# 3     Chi Ku Pan-Asian Kitchen, 1732 W 5400 S, Salt ...
# 4     Man Yee Express, 121 Loudon Rd, Concord, NH 03301
# ...                                                 ...
# 3117  Fin, The Mirage, 3400 S Las Vegas Blvd, Las Ve...
# 3118  Second Street Grill, 200 E Fremont St, Las Veg...
# 3119           Tek Nique, 170 NH-101, Bedford, NH 03110
# 3120  Pago, 878 S 900 E, Salt Lake City, UT 84102, U...
# 3121  Il Angolo Resto-Bar, 527 W College Ave, Applet...
#
#                                     gmap_id  \
# 0     0x88008ff5b3c52fd3:0xdbe482cf9fb221db
# 1     0x89e24fa02483a9ab:0x718d70964f700fd6
# 2     0x4d557136b874c5db:0x34af0bdfbe0c964c
# 3     0x87528be4d10bcaeb:0x9ef8dd3c99a7a5ad
# 4     0x89e26bceb6222f8d:0x4f09e6e878167429
# ...                                     ...
# 3117  0x80c8c415f0a42c77:0x3f4484aa0b0b7b2f
# 3118  0x80c8c3a03b613215:0x7e558167996b99ed
# 3119  0x89e24bca0ba183fd:0xb556f168cfa7c01c
# 3120  0x8752f55a5a0cd297:0xd41050b21799f209
# 3121  0x8803b7319ee2f3d7:0x7460b4278c654c64
#
#                                             description   latitude  \
# 0                                                  None  44.306954
# 1                                                  None  42.986138
# 2                                                  None  45.453699
# 3                                                  None  40.653806
# 4                                                  None  43.214048
# ...                                                 ...        ...
# 3117  Sophisticated retreat from Mirage casino floor...  36.121603
# 3118  Pacific Rim-inspired American steak & seafood ...  36.170757
# 3119  Eclectic modern American cooking, including lo...  42.941116
# 3120  Compact New American hot spot with inventive d...  40.750131
# 3121  Polished venue for upmarket Mediterranean cuis...  44.261675
#
#        longitude                                           category price  \
# 0     -89.845783                                     ['Restaurant']  None
# 1     -71.445091                                     ['Restaurant']  None
# 2     -89.796499                                     ['Restaurant']  None
# 3    -111.939851                                     ['Restaurant']  None
# 4     -71.512284                                     ['Restaurant']  None
# ...          ...                                                ...   ...
# 3117 -115.174439  ['Chinese restaurant', 'Asian restaurant', 'Ba...   $$$
# 3118 -115.143130  ['Steak house', 'American restaurant', 'Bar', ...   $$$
# 3119  -71.519275  ['Fine dining restaurant', 'American restauran...   $$$
# 3120 -111.865611  ['American restaurant', 'Caterer', 'Fine dinin...   $$$
# 3121  -88.413301  ['Fine dining restaurant', 'Bar', 'Catering fo...   $$$
#
#                                                   hours  \
# 0     [['Thursday', '12–11PM'], ['Friday', '12PM–12A...
# 1     [['Thursday', '8:30AM–7PM'], ['Friday', '8:30A...
# 2     [['Thursday', '2–10PM'], ['Friday', '2–10PM'],...
# 3     [['Thursday', '11AM–10PM'], ['Friday', '11AM–1...
# 4     [['Thursday', '10AM–9:30PM'], ['Friday', '10AM...
# ...                                                 ...
# 3117  [['Monday', '5–10PM'], ['Tuesday', '5–10PM'], ...
# 3118  [['Sunday', '5–10PM'], ['Monday', 'Closed'], [...
# 3119  [['Sunday', '10AM–2PM'], ['Monday', 'Closed'],...
# 3120  [['Saturday', '10AM–2PM'], ['Sunday', '10AM–2P...
# 3121  [['Saturday', '5–10PM'], ['Sunday', 'Closed'],...
#
#                                                    MISC  \
# 0     {'Service options': ['Takeout', 'Dine-in', 'De...
# 1     {'Service options': ['Takeout'], 'Popular for'...
# 2     {'Service options': ['Takeout', 'Dine-in', 'De...
# 3     {'Service options': ['Outdoor seating', 'Deliv...
# 4     {'Service options': ['Delivery', 'Takeout'], '...
# ...                                                 ...
# 3117  {'Service options': ['Takeout', 'Delivery'], '...
# 3118  {'Service options': ['Delivery', 'Takeout'], '...
# 3119                  {'Service options': ['Delivery']}
# 3120  {'Service options': ['Outdoor seating', 'Curbs...
# 3121  {'Service options': ['Takeout', 'Delivery'], '...
#
#                                                     url
# 0     https://www.google.com/maps/place//data=!4m2!3...
# 1     https://www.google.com/maps/place//data=!4m2!3...
# 2     https://www.google.com/maps/place//data=!4m2!3...
# 3     https://www.google.com/maps/place//data=!4m2!3...
# 4     https://www.google.com/maps/place//data=!4m2!3...
# ...                                                 ...
# 3117  https://www.google.com/maps/place//data=!4m2!3...
# 3118  https://www.google.com/maps/place//data=!4m2!3...
# 3119  https://www.google.com/maps/place//data=!4m2!3...
# 3120  https://www.google.com/maps/place//data=!4m2!3...
# 3121  https://www.google.com/maps/place//data=!4m2!3...
#
# [3122 rows x 11 columns]
