# %%
import pandas as pd
import matplotlib as mpl
import ast

# %%
Rest_google = pd.read_csv('./Datasets/Restaurantes_Google.csv',delimiter=',')
Rest_google.head()
# Out:
#                             name  \
# 0            Roux's Roadhouse 73
# 1  Crepes n' Tacos Mexican Grill
# 2                   The Big Eazy
# 3                         Subway
# 4                  Papa Kelsey's
#
#                                              address  \
# 0  Roux's Roadhouse 73, 784 WI-73, Nekoosa, WI 54457
# 1  Crepes n' Tacos Mexican Grill, suit #5, 5390, ...
# 2  The Big Eazy, 2053 N Doctor M.L.K. Jr Dr, Milw...
# 3        Subway, 250 E Wolf Run, Mukwonago, WI 53149
# 4       Papa Kelsey's, 165 E 1400 N, Logan, UT 84341
#
#                                  gmap_id  \
# 0  0x88008ff5b3c52fd3:0xdbe482cf9fb221db
# 1  0x80c8db636d525e3b:0x6a51cce4b2dcc350
# 2  0x8805196ab8890a87:0x837a93dd92ed9d4f
# 3  0x8805a2a887bbe777:0xb6c14a56e8897c0f
# 4   0x87547de0ed23364d:0x5b25d19bde61e5d
#
#                                          description   latitude   longitude  \
# 0                                                NaN  44.306954  -89.845783
# ...

# %%
Rest_google.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
Rest_yelp = pd.read_csv('./Datasets/Restaurantes_Yelp.csv',delimiter=',')
Rest_yelp.head()
# Out:
#               business_id                                 name  \
# 0  MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 1  9OG5YkX1g2GReZM0AskizA              Romano's Macaroni Grill
# 2  tMkwHmWFUEXrC9ZduonpTg                   The Green Pheasant
# 3  2xVsWBNFwZOxIOdd9Mwnww             Cheeseburger In Paradise
# 4  ljxNT9p0y7YMPx0fcNBGig  Tony's Restaurant & 3rd Street Cafe
#
#                 address          city state postal_code   latitude  \
# 0           935 Race St  Philadelphia    CA       19107  39.955505
# 1    5505 S Virginia St          Reno    AB       89502  39.476117
# 2         215 1st Ave S     Nashville    TN       37201  36.159886
# 3  116 N Pottstown Pike         Exton    PA       19341  40.029962
# 4          312 Piasa St         Alton    IL       62002  38.896563
#
#     longitude  stars  review_count  is_open  \
# 0  -75.155564    4.0            80        1
# 1 -119.789339    2.5           339        1
# ...

# %%
Rest_yelp.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
Rest_yelp.shape
# Out:
# (15305, 14)

# %%
Rest_yelp.isna().sum()
# Out:
# business_id        0
# name               0
# address           86
# city               0
# state              0
# postal_code        4
# latitude           0
# longitude          0
# stars              0
# review_count       0
# is_open            0
# attributes       177
# categories         0
# hours           2743
# dtype: int64

# %%
for a in Rest_google['category']:
    if 'Truck stop' in a:
        print(a)
# Out:
# ['Gas station', 'Restaurant', 'Store', 'Truck stop', 'Trucking company']
# ['Gas station', 'Beer store', 'Convenience store', 'Diesel fuel supplier', 'Ice supplier', 'Lottery retailer', 'Propane supplier', 'Restaurant', 'Truck stop', 'Wine store']
# ['Gas station', 'ATM', 'Beer store', 'Coffee shop', 'Convenience store', 'Diesel fuel supplier', 'Fast food restaurant', 'Pizza Takeout', 'Truck stop']
# ['Gas station', 'ATM', 'Bait shop', 'Coffee shop', 'Convenience store', 'Diesel fuel supplier', 'Fast food restaurant', 'Liquor store', 'Pizza Takeout', 'Truck stop']
# ['Truck stop', 'Convenience store', 'Fast food restaurant', 'Gas station', 'Truck repair shop']

# %%
type(Rest_google['category'][0])
# Out:
# str

# %%
def desglose(columna):
    lista_categorias = []
    for row in columna:
        if row:
            palabras = row.split(',')
            for palabra in palabras:
                palabra = palabra.strip()  # Eliminar espacios en blanco alrededor de la palabra
                if palabra not in lista_categorias:
                    lista_categorias.append(palabra)
    return lista_categorias

# %%
categorias_yelp =  desglose(Rest_yelp['categories'])

# %%
len(categorias_yelp)
# Out:
# 406

# %%
categorias_yelp
# Out:
# ['Restaurants',
#  'Food',
#  'Bubble Tea',
#  'Coffee & Tea',
#  'Bakeries',
#  'Italian',
#  'Japanese',
#  'Seafood',
#  'Burgers',
#  'Specialty Food',
#  'Steakhouses',
#  'Pizza',
#  'Pasta Shops',
#  'Chinese',
#  'American (New)',
#  'Soup',
#  'Automotive',
#  'Delis',
#  'Gas Stations',
#  'Sandwiches',
#  'Convenience Stores',
#  'Sushi Bars',
#  'Asian Fusion',
#  'Food Trucks',
#  'Cajun/Creole',
#  'French',
#  'Moroccan',
#  'Mediterranean',
#  'Filipino',
#  'Barbeque',
#  'Chicken Wings',
#  'Fast Food',
#  'Caterers',
#  'Bagels',
#  'Event Planning & Services',
#  'Breakfast & Brunch',
#  'American (Traditional)',
#  'Vegan',
#  'Nightlife',
#  'Bars',
#  'Cocktail Bars',
#  'Tapas/Small Plates',
#  'Lounges',
#  'Coffee Roasteries',
#  'Acai Bowls',
#  'Organic Stores',
#  'Vegetarian',
#  'Juice Bars & Smoothies',
#  'Southern',
#  'Salad',
#  'Pakistani',
#  'Indian',
#  'Food Delivery Services',
#  'Halal',
#  'Mexican',
#  'Buffets',
#  'Diners',
# ...

# %%
Rest_google['category'] = Rest_google['category'].apply(lambda x: eval(x))

# %%
def desglose(columna):
    lista_categorias = []
    for row in columna:
        if row:
            for palabra in row:
                palabra = palabra.strip()  # Eliminar espacios en blanco alrededor de la palabra
                if palabra not in lista_categorias:
                    lista_categorias.append(palabra)
    return lista_categorias

# %%
categorias_google = desglose(Rest_google['category'])

# %%
len(categorias_google)
# Out:
# 405

# %%
categorias_google
# Out:
# ['Restaurant',
#  'Mexican restaurant',
#  'Crêperie',
#  'Ice cream shop',
#  'Taco restaurant',
#  'Cajun restaurant',
#  'Creole restaurant',
#  'Sandwich shop',
#  'Caterer',
#  'Fast food restaurant',
#  'Takeout Restaurant',
#  'Pizza restaurant',
#  'Peruvian restaurant',
#  'Lunch restaurant',
#  'Delivery Restaurant',
#  'Seafood restaurant',
#  'Vegan restaurant',
#  'Vegetarian restaurant',
#  'Food court',
#  'Family restaurant',
#  'Pizza delivery',
#  'Pizza Takeout',
#  'Hot dog restaurant',
#  'American restaurant',
#  'Dessert restaurant',
#  'Hamburger restaurant',
#  'Salad shop',
#  'Soup restaurant',
#  'Deli',
#  'Bagel shop',
#  'South Asian restaurant',
#  'Sushi restaurant',
#  'Asian fusion restaurant',
#  'Japanese restaurant',
#  'Sushi takeaway',
#  'Asian restaurant',
#  'Bakery',
#  'Bar',
#  'Italian restaurant',
#  'Chinese restaurant',
#  'Fine dining restaurant',
#  'Live music bar',
#  'Food products supplier',
#  'Restaurant supply store',
# ...

# %%
total = set(categorias_yelp).union(set(categorias_google))

# %%
lista_completa = list(total)

# %%
len(lista_completa)
# Out:
# 808

# %%
lista_completa
# Out:
# ['Mexican torta restaurant',
#  'Internet cafe',
#  'Conference center',
#  'Pet groomer',
#  'Car Wash',
#  'Breweries',
#  'Ramen restaurant',
#  'Gyms',
#  'Lounges',
#  'Spanish restaurant',
#  'Drive-Thru Bars',
#  'Delivery Chinese restaurant',
#  'Delivery service',
#  'Patisserie/Cake Shop',
#  'Pool hall',
#  'Uniform store',
#  'Golf',
#  'Watches',
#  'Vitamin & supplements store',
#  'Gun/Rifle Ranges',
#  'Brazilian restaurant',
#  'Indian Muslim restaurant',
#  'Beer garden',
#  'Carpet Cleaning',
#  'Performing arts theater',
#  'Mass Media',
#  'Religious Items',
#  'Chicken restaurant',
#  'Hot Dogs',
#  'Cuban restaurant',
#  'Filipino',
#  'Polish',
#  'Nepalese restaurant',
#  'Sri Lankan',
#  'Chicken wings restaurant',
#  'Hakka',
#  'Scandinavian',
#  'Oil change service',
#  'Golf shop',
#  'South Asian restaurant',
#  'Wellness center',
#  'Tapas restaurant',
#  'Outdoor Gear',
#  'Bowling',
#  'Fish & chips restaurant',
#  'Herbal Shops',
#  'Trinidadian',
# ...

# %%
for a in lista_completa:
    if 'Restaurant' in a:
        print(a)
# Out:
# Delivery Restaurant
# Restaurant
# Restaurants
# Restaurant supply store
# Pop-Up Restaurants
# Restaurant or cafe
# Restaurant Supplies
# Takeout Restaurant
